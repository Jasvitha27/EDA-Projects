# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
df['director']=df['director'].fillna('Unknown')

# %%
df['cast']=df['cast'].fillna('Unknown')

# %%
df['country']=df['country'].fillna('Unknown')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df['date_added'] = pd.to_datetime(df['date_added'],errors='coerce')
df['year_added'] = df['date_added'].dt.year

# %%
df = df.dropna(subset=['date_added'])

# %%
df['year_added'] = df['date_added'].dt.year

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          4
# duration        3
# listed_in       0
# description     0
# year_added      0
# dtype: int64

# %%
df['rating']=df['rating'].fillna(df['rating'].mode()[0])

# %%
df['duration']=df['duration'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# year_added      0
# dtype: int64

# %% [markdown]
# 1️⃣ Movies vs TV Shows (numbers + plot)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2578
# Name: count, dtype: int64

# %%
sns.countplot(x='type',data=df)
plt.title('Movie vs TV shows on Netflix')
plt.show()

# %% [markdown]
# 2️⃣ Content added per year (important insight)

# %%
df['year_added'].value_counts().sort_index()
# Out:
# year_added
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      10
# 2014      23
# 2015      73
# 2016     418
# 2017    1164
# 2018    1625
# 2019    1999
# 2020    1878
# 2021    1498
# Name: count, dtype: int64

# %%
df['year_added'].value_counts().sort_index().plot(kind='line',figsize=(10,4))
plt.title("Netflix content added per year")
plt.show()

# %% [markdown]
# 3️⃣ Top 10 countries

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2778
# India              971
# Unknown            827
# United Kingdom     403
# Japan              241
# South Korea        195
# Canada             173
# Spain              141
# France             122
# Mexico             110
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10).plot(kind='bar',figsize=(10,4))
plt.title('Top 10 content producing countries')
plt.show()

# %% [markdown]
# 4️⃣ Most common ratings

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3187
# TV-14       2133
# TV-PG        838
# R            799
# PG-13        490
# TV-Y7        330
# TV-Y         300
# PG           287
# TV-G         212
# NR            78
# G             41
# TV-Y7-FV       5
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['rating'].value_counts().plot(kind='bar')
plt.title('Distribution of content ratings')
plt.show()

# %% [markdown]
# 5️⃣ Top genres (very common interview question)

# %%
df['listed_in'] .str.split(', ') .explode().value_counts().head(10)
# Out:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1328
# Documentaries                869
# Action & Adventure           859
# Independent Movies           756
# TV Dramas                    739
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
df['listed_in'].str.split(', ').explode().value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Genres on Netflix')
plt.show()

# %% [markdown]
# 6️⃣ Quick filters (practice)

# %%
df[(df['type']=='Movie') & (df['rating']=='TV-MA')].head()
# Out:
#    show_id   type                                              title  \
# 7       s8  Movie                                            Sankofa
# 12     s13  Movie                                       Je Suis Karl
# 16     s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 35     s36  Movie                     The Father Who Moves Mountains
# 36     s37  Movie                                     The Stronghold
#
#                                          director  \
# 7                                    Haile Gerima
# 12                            Christian Schwochow
# 16  Pedro de Echave García, Pablo Azorín Williams
# 35                                   Daniel Sandu
# 36                                 Cédric Jimenez
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 16                                            Unknown
# ...

# %%
df[(df['country']=='India') & (df['type']=='Movie')].head()
# Out:
#     show_id   type             title              director  \
# 24      s25  Movie             Jeans            S. Shankar
# 105    s106  Movie  Angamaly Diaries  Lijo Jose Pellissery
# 114    s115  Movie            Anjaam          Rahul Rawail
# 116    s117  Movie            Dhanak       Nagesh Kukunoor
# 118    s119  Movie           Gurgaon         Shanker Raman
#
#                                                   cast country date_added  \
# 24   Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India 2021-09-21
# 105  Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India 2021-09-05
# 114  Madhuri Dixit, Shah Rukh Khan, Tinnu Anand, Jo...   India 2021-09-02
# 116  Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...   India 2021-09-02
# 118  Akshay Oberoi, Pankaj Tripathi, Ragini Khanna,...   India 2021-09-02
#
#      release_year rating duration  \
# 24           1998  TV-14  166 min
# 105          2017  TV-14  128 min
# 114          1994  TV-14  143 min
# ...

# %% [markdown]
# 8️⃣ Movie duration analysis (optional but nice)

# %%
movies = df[df['type'] == 'Movie'].copy()

movies['duration_mins'] = movies['duration'].str.replace(' min', '', regex=False)
movies = movies[movies['duration_mins'] != 'Unknown']
movies['duration_mins'] = movies['duration_mins'].astype(int)

# %%
movies['duration_mins'].describe()
# Out:
# count    6128.000000
# mean       99.577187
# std        28.290593
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: duration_mins, dtype: float64

# %%
movies['duration_mins'].plot(kind='hist', bins=30, figsize=(8,4))
plt.title("Distribution of Movie Durations")
plt.show()

# %% [markdown]
# 9️⃣ TV Shows seasons analysis

# %%
tv = df[df['type'] == 'TV Show'].copy()

tv['seasons'] = tv['duration'].str.replace(' Seasons', '').str.replace(' Season', '')
tv = tv[tv['seasons'] != 'Unknown']
tv['seasons'] = tv['seasons'].astype(int)

# %%
tv['seasons'].value_counts().head()
# Out:
# seasons
# 1    1791
# 2     384
# 3     178
# 4      89
# 5      55
# Name: count, dtype: int64

# %% [markdown]
# 🔟 Content growth: Movies vs TV Shows over time

# %%
pd.crosstab(df['year_added'], df['type']).plot(figsize=(10,4))
plt.title("Movies vs TV Shows Added Over Years")
plt.show()

# %% [markdown]
# 1️⃣1️⃣ Top directors (simple)

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Unknown                   2541
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Suhas Kadav                 16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Jay Chapman                 12
# Youssef Chahine             12
# Martin Scorsese             12
# Name: count, dtype: int64

# %% [markdown]
# 1️⃣2️⃣ FINAL INSIGHTS (just remember, don’t code)
#
# Netflix adds more movies than TV shows every year
#
# Content growth increased rapidly after 2016
#
# Most movies are between 80–120 minutes
#
# Majority of TV shows have 1–2 seasons
